# %%
import MySQLdb

# Conectar ao banco de dados
db_connection = MySQLdb.connect(
    host="127.0.0.1",
    user="root",
    password="123_456",
    database="cristiano_ronaldo"
)

# Criar um cursor para interagir com o banco de dados
cursor = db_connection.cursor()

# Exemplo de consulta
cursor.execute("SELECT * FROM cr7_stats")

# Exibir os resultados
for row in cursor.fetchall():
    print(row)

# Fechar a conexão
cursor.close()
db_connection.close()
# Out:
# (1, '24/25', 'Saudi Pro League', 'Saudi Pro League', 'Al-Nassr FC', '24', '19', '3', '2 / - / -', '2.085')
# (2, '24/25', 'AFC Champions League Elite', 'AFC Champions League Elite', 'Al-Nassr FC', '6', '7', '-', '- / - / -', '504')
# (3, '24/25', 'Kings Cup', 'Kings Cup', 'Al-Nassr FC', '1', '-', '-', '- / - / -', '90')
# (4, '24/25', 'Saudi Super Cup', 'Saudi Super Cup', 'Al-Nassr FC', '2', '2', '1', '- / - / -', '171')
# (5, '23/24', 'Kings Cup', 'Kings Cup', 'Al-Nassr FC', '4', '3', '-', '1 / - / -', '412')
# (6, '23/24', 'Saudi Pro League', 'Saudi Pro League', 'Al-Nassr FC', '31', '35', '11', '2 / - / -', '2.648')
# (7, '23/24', 'Saudi Super Cup', 'Saudi Super Cup', 'Al-Nassr FC', '1', '-', '-', '- / - / 1', '86')
# (8, '23/24', 'AFC Champions League (- 2024)', 'AFC Champions League', 'Al-Nassr FC', '8', '6', '1', '1 / - / -', '738')
# (9, '23/24', 'AFC Champions League Play-Off', 'AFC CL Play-Off', 'Al-Nassr FC', '1', '-', '1', '- / - / -', '90')
# (10, '22/23', 'Saudi Pro League', 'Saudi Pro League', 'Al-Nassr FC', '16', '14', '2', '3 / - / -', '1.434')
# (11, '22/23', 'Kings Cup', 'Kings Cup', 'Al-Nassr FC', '2', '-', '-', '1 / - / -', '177')
# (12, '22/23', 'Saudi Super Cup', 'Saudi Super Cup', 'Al-Nassr FC', '1', '-', '-', '- / - / -', '90')
# (13, '22/23', 'Premier League', 'Premier League', 'Manchester United FC', '10', '1', '-', '2 / - / -', '520')
# (14, '22/23', 'Liga Europa', 'Liga Europa', 'Manchester United FC', '6', '2', '2', '1 / - / -', '531')
# (15, '21/22', 'Premier League', 'Premier League', 'Manchester United FC', '30', '18', '3', '8 / - / -', '2.459')
# (16, '21/22', 'Liga dos Campeões', 'Liga dos Campeões', 'Manchester United FC', '7', '6', '-', '1 / - / -', '612')
# (17, '21/22', 'Copa da Inglaterra', 'Copa da Inglaterra', 'Manchester United FC', '1', '-', '-', '- / - / -', '120')
# (18, '21/22', 'Serie A', 'Serie A', 'Juventus FC', '1', '-', '-', '1 / - / -', '30')
# (19, '20/21', 'Serie A', 'Serie A', 'Juventus FC', '33', '29', '2', '3 / - / -', '2.803')
# (20, '20/21', 'Copa da Itália', 'Copa da Itália', 'Juventus FC', '4', '2', '-', '1 / - / -', '288')
# (21, '20/21', 'Liga dos Campeões', 'Liga dos Campeões', 'Juventus FC', '6', '4', '2', '- / - / -', '570')
# (22, '20/21', 'Supercopa da Itália', 'Supercopa da Itália', 'Juventus FC', '1', '1', '-', '1 / - / -', '90')
# (23, '19/20', 'Liga dos Campeões', 'Liga dos Campeões', 'Juventus FC', '8', '4', '1', '- / - / -', '712')
# (24, '19/20', 'Serie A', 'Serie A', 'Juventus FC', '33', '31', '6', '3 / - / -', '2.919')
# (25, '19/20', 'Copa da Itália', 'Copa da Itália', 'Juventus FC', '4', '2', '-', '- / - / -', '360')
# (26, '19/20', 'Supercopa da Itália', 'Supercopa da Itália', 'Juventus FC', '1', '-', '-', '- / - / -', '90')
# (27, '18/19', 'Serie A', 'Serie A', 'Juventus FC', '31', '21', '9', '3 / - / -', '2.689')
# (28, '18/19', 'Liga dos Campeões', 'Liga dos Campeões', 'Juventus FC', '9', '6', '2', '1 / - / 1', '749')
# (29, '18/19', 'Copa da Itália', 'Copa da Itália', 'Juventus FC', '2', '-', '-', '- / - / -', '118')
# (30, '18/19', 'Supercopa da Itália', 'Supercopa da Itália', 'Juventus FC', '1', '1', '-', '- / - / -', '90')
# (31, '17/18', 'Liga dos Campeões', 'Liga dos Campeões', 'Real Madrid CF', '13', '15', '3', '2 / - / -', '1.170')
# (32, '17/18', 'LaLiga', 'LaLiga', 'Real Madrid CF', '27', '26', '5', '1 / - / -', '2.297')
# (33, '2018', 'Mundial de Clubes', 'Mundial de Clubes', 'Real Madrid CF', '2', '2', '-', '- / - / -', '180')
# (34, '17/18', 'Supercopa da Espanha', 'Supercopa da Espanha', 'Real Madrid CF', '1', '1', '-', '- / 1 / -', '24')
# (35, '17/18', 'Supercopa da UEFA', 'Supercopa da UEFA', 'Real Madrid CF', '1', '-', '-', '- / - / -', '7')
# (36, '16/17', 'Liga dos Campeões', 'Liga dos Campeões', 'Real Madrid CF', '13', '12', '6', '1 / - / -', '1.200')
# (37, '16/17', 'LaLiga', 'LaLiga', 'Real Madrid CF', '29', '25', '6', '4 / - / -', '2.544')
# (38, '16/17', 'Copa do Rei', 'Copa do Rei', 'Real Madrid CF', '2', '1', '-', '- / - / -', '180')
# (39, '2017', 'Mundial de Clubes', 'Mundial de Clubes', 'Real Madrid CF', '2', '4', '-', '- / - / -', '202')
# (40, '15/16', 'Liga dos Campeões', 'Liga dos Campeões', 'Real Madrid CF', '12', '16', '4', '1 / - / -', '1.109')
# (41, '15/16', 'LaLiga', 'LaLiga', 'Real Madrid CF', '36', '35', '11', '2 / - / -', '3.184')
# (42, '14/15', 'LaLiga', 'LaLiga', 'Real Madrid CF', '35', '48', '17', '4 / - / 1', '3.099')
# (43, '14/15', 'Liga dos Campeões', 'Liga dos Campeões', 'Real Madrid CF', '12', '10', '4', '1 / - / -', '1.065')
# (44, '14/15', 'Copa do Rei', 'Copa do Rei', 'Real Madrid CF', '2', '1', '-', '- / - / -', '117')
# (45, '2015', 'Mundial de Clubes', 'Mundial de Clubes', 'Real Madrid CF', '2', '-', '2', '- / - / -', '180')
# (46, '14/15', 'Supercopa da Espanha', 'Supercopa da Espanha', 'Real Madrid CF', '2', '-', '-', '1 / - / -', '90')
# (47, '14/15', 'Supercopa da UEFA', 'Supercopa da UEFA', 'Real Madrid CF', '1', '2', '-', '- / - / -', '90')
# (48, '13/14', 'Liga dos Campeões', 'Liga dos Campeões', 'Real Madrid CF', '11', '17', '5', '1 / - / -', '993')
# (49, '13/14', 'LaLiga', 'LaLiga', 'Real Madrid CF', '30', '31', '11', '4 / - / 1', '2.540')
# (50, '13/14', 'Copa do Rei', 'Copa do Rei', 'Real Madrid CF', '6', '3', '1', '2 / - / -', '497')
# (51, '12/13', 'Copa do Rei', 'Copa do Rei', 'Real Madrid CF', '7', '7', '1', '2 / - / 1', '655')
# (52, '12/13', 'LaLiga', 'LaLiga', 'Real Madrid CF', '34', '34', '11', '9 / - / -', '2.717')
# (53, '12/13', 'Liga dos Campeões', 'Liga dos Campeões', 'Real Madrid CF', '12', '12', '1', '1 / - / -', '1.080')
# (54, '12/13', 'Supercopa da Espanha', 'Supercopa da Espanha', 'Real Madrid CF', '2', '2', '-', '- / - / -', '180')
# (55, '11/12', 'LaLiga', 'LaLiga', 'Real Madrid CF', '38', '46', '12', '4 / - / -', '3.354')
# (56, '11/12', 'Liga dos Campeões', 'Liga dos Campeões', 'Real Madrid CF', '10', '10', '3', '1 / - / -', '930')
# (57, '11/12', 'Copa do Rei', 'Copa do Rei', 'Real Madrid CF', '5', '3', '-', '1 / - / -', '438')
# (58, '11/12', 'Supercopa da Espanha', 'Supercopa da Espanha', 'Real Madrid CF', '2', '1', '-', '1 / - / -', '180')
# (59, '10/11', 'LaLiga', 'LaLiga', 'Real Madrid CF', '34', '40', '13', '2 / - / -', '2.913')
# (60, '10/11', 'Liga dos Campeões', 'Liga dos Campeões', 'Real Madrid CF', '12', '6', '4', '2 / - / -', '1.021')
# (61, '10/11', 'Copa do Rei', 'Copa do Rei', 'Real Madrid CF', '8', '7', '1', '3 / - / -', '684')
# (62, '09/10', 'LaLiga', 'LaLiga', 'Real Madrid CF', '29', '26', '9', '3 / 1 / 1', '2.465')
# (63, '09/10', 'Liga dos Campeões', 'Liga dos Campeões', 'Real Madrid CF', '6', '7', '1', '- / - / -', '450')
# (64, '08/09', 'Liga dos Campeões', 'Liga dos Campeões', 'Manchester United FC', '12', '4', '3', '2 / - / -', '1.010')
# (65, '08/09', 'Premier League', 'Premier League', 'Manchester United FC', '33', '18', '7', '5 / 1 / -', '2.745')
# (66, '08/09', 'Copa da Liga Inglesa', 'Copa da Liga Inglesa', 'Manchester United FC', '4', '2', '-', '1 / - / -', '240')
# (67, '08/09', 'Copa da Inglaterra', 'Copa da Inglaterra', 'Manchester United FC', '2', '1', '1', '- / - / -', '144')
# (68, '2009', 'Mundial de Clubes', 'Mundial de Clubes', 'Manchester United FC', '2', '1', '1', '- / - / -', '180')
# (69, '07/08', 'Liga dos Campeões', 'Liga dos Campeões', 'Manchester United FC', '11', '8', '1', '2 / - / -', '1.017')
# (70, '07/08', 'Premier League', 'Premier League', 'Manchester United FC', '34', '31', '7', '5 / - / 1', '2.747')
# (71, '07/08', 'Copa da Inglaterra', 'Copa da Inglaterra', 'Manchester United FC', '3', '3', '-', '- / - / -', '270')
# (72, '07/08', 'Supercopa da Inglaterra', 'Supercopa da Inglaterra', 'Manchester United FC', '1', '-', '-', '- / - / -', '120')
# (73, '06/07', 'Copa da Inglaterra', 'Copa da Inglaterra', 'Manchester United FC', '7', '3', '1', '- / - / -', '558')
# (74, '06/07', 'Premier League', 'Premier League', 'Manchester United FC', '34', '17', '8', '2 / - / -', '2.788')
# (75, '06/07', 'Liga dos Campeões', 'Liga dos Campeões', 'Manchester United FC', '11', '3', '5', '3 / - / -', '951')
# (76, '06/07', 'Copa da Liga Inglesa', 'Copa da Liga Inglesa', 'Manchester United FC', '1', '-', '-', '- / - / -', '90')
# (77, '05/06', 'Premier League', 'Premier League', 'Manchester United FC', '33', '9', '6', '8 / - / 1', '2.286')
# (78, '05/06', 'Copa da Liga Inglesa', 'Copa da Liga Inglesa', 'Manchester United FC', '4', '2', '1', '1 / - / -', '343')
# (79, '05/06', 'Copa da Inglaterra', 'Copa da Inglaterra', 'Manchester United FC', '2', '-', '-', '- / - / -', '121')
# (80, '05/06', 'Liga dos Campeões', 'Liga dos Campeões', 'Manchester United FC', '6', '-', '-', '1 / - / -', '506')
# (81, '05/06', 'Qualificação Liga dos Campeões', 'Qualificação Liga dos Campeões', 'Manchester United FC', '2', '1', '1', '- / - / -', '157')
# (82, '04/05', 'Copa da Inglaterra', 'Copa da Inglaterra', 'Manchester United FC', '7', '4', '3', '1 / - / -', '545')
# (83, '04/05', 'Premier League', 'Premier League', 'Manchester United FC', '33', '5', '4', '3 / - / -', '2.425')
# (84, '04/05', 'Liga dos Campeões', 'Liga dos Campeões', 'Manchester United FC', '7', '-', '2', '- / - / -', '502')
# (85, '04/05', 'Copa da Liga Inglesa', 'Copa da Liga Inglesa', 'Manchester United FC', '2', '-', '-', '1 / - / -', '180')
# (86, '04/05', 'Qualificação Liga dos Campeões', 'Qualificação Liga dos Campeões', 'Manchester United FC', '1', '-', '-', '- / - / -', '64')
# (87, '03/04', 'Copa da Inglaterra', 'Copa da Inglaterra', 'Manchester United FC', '5', '2', '3', '- / - / -', '436')
# (88, '03/04', 'Premier League', 'Premier League', 'Manchester United FC', '29', '4', '4', '3 / 1 / -', '1.551')
# (89, '03/04', 'Liga dos Campeões', 'Liga dos Campeões', 'Manchester United FC', '5', '-', '1', '- / - / -', '291')
# (90, '03/04', 'Copa da Liga Inglesa', 'Copa da Liga Inglesa', 'Manchester United FC', '1', '-', '-', '- / - / -', '77')
# (91, '02/03', 'Liga Portugal', 'SuperLiga', 'Sporting CP', '25', '3', '5', '1 / - / -', '1.069')
# (92, '02/03', 'Taça de Portugal', 'Taça de Portugal', 'Sporting CP', '3', '2', '-', '- / - / -', '172')
# (93, '02/03', 'Taça UEFA (- 2009)', 'Taça UEFA', 'Sporting CP', '2', '-', '1', '- / - / -', '119')
# (94, '02/03', 'Supertaça Cândido de Oliveira', 'Supertaça', 'Sporting CP', '-', '-', '-', '- / - / -', '-')
# (95, '02/03', 'Qualificação Liga dos Campeões', 'Qualificação Liga dos Campeões', 'Sporting CP', '1', '-', '-', '- / - / -', '32')
